# %% [markdown]
# <a href="https://colab.research.google.com/github/sarapallejyo2006/sarapalle-jyothi/blob/master/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# used for numerical calculations
import numpy as np
# used for handling datasets
import pandas as pd
# used for visualization
import matplotlib.pyplot as plt
# split dataset into training and testing
from sklearn.model_selection import train_test_split
# Linear Regression algorithm
from sklearn.linear_model import LinearRegression
# Evaluation Metrics
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-090c32d5-77b5-4900-ab4d-e541ece1d9ca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-090c32d5-77b5-4900-ab4d-e541ece1d9ca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Real_Estate_Price_Prediction_Dataset (3).csv')
df.head()
# Out:
#    Area  Bedrooms  Bathrooms  Age  Distance_City  Parking   Price
# 0  3774         2          3    6             10        1  225.66
# 1  1460         3          4    1             18        1  100.39
# 2  1894         4          1   24              8        1  108.16
# 3  1730         2          3   15              8        0  109.02
# 4  1695         1          1   28              7        0   51.11

# %%
#frist head of five records
df.head()
# Out:
#    Area  Bedrooms  Bathrooms  Age  Distance_City  Parking   Price
# 0  3774         2          3    6             10        1  225.66
# 1  1460         3          4    1             18        1  100.39
# 2  1894         4          1   24              8        1  108.16
# 3  1730         2          3   15              8        0  109.02
# 4  1695         1          1   28              7        0   51.11

# %%
#last tail of five records
df.tail()
# Out:
#      Area  Bedrooms  Bathrooms  Age  Distance_City  Parking   Price
# 295  2402         4          3   14              9        0  154.90
# 296  3120         3          3   26             22        0  147.14
# 297  2569         5          2    4             22        0  165.31
# 298  2798         4          4   25             11        0  180.54
# 299  2038         5          1   13             14        1  107.29

# %%
#shape of data
df.shape
# Out:
# (300, 7)

# %%
#Give the data information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Area           300 non-null    int64
#  1   Bedrooms       300 non-null    int64
#  2   Bathrooms      300 non-null    int64
#  3   Age            300 non-null    int64
#  4   Distance_City  300 non-null    int64
#  5   Parking        300 non-null    int64
#  6   Price          300 non-null    float64
# dtypes: float64(1), int64(6)
# memory usage: 16.5 KB

# %%
#describe about table
df.describe()
# Out:
#               Area    Bedrooms   Bathrooms         Age  Distance_City  \
# count   300.000000  300.000000  300.000000  300.000000     300.000000
# mean   2371.990000    3.013333    2.343333   14.636667      12.633333
# std     942.766953    1.446882    1.111865    8.389234       7.203136
# min     601.000000    1.000000    1.000000    1.000000       1.000000
# 25%    1620.750000    2.000000    1.000000    6.750000       7.000000
# 50%    2342.500000    3.000000    2.000000   15.000000      13.000000
# 75%    3206.000000    4.000000    3.000000   22.000000      19.000000
# max    3997.000000    5.000000    4.000000   29.000000      24.000000
#
#           Parking       Price
# count  300.000000  300.000000
# mean     0.463333  134.740000
# std      0.499487   54.747112
# min      0.000000    4.680000
# 25%      0.000000   95.195000
# 50%      0.000000  132.535000
# 75%      1.000000  179.002500
# max      1.000000  258.260000

# %%
#step 10 check missing values
df.isnull().sum()
# Out:
# Area             0
# Bedrooms         0
# Bathrooms        0
# Age              0
# Distance_City    0
# Parking          0
# Price            0
# dtype: int64

# %%
#step 11 duplicate records
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#step 12 Histogram of area
plt.figure(figsize=(8,5))
plt.hist(df["Area"],bins=20)
plt.title("Distribution of Area")
plt.xlabel("Area (Square Feet)")
plt.ylabel("Frequency")
plt.show()

# %%
#step 13 Histogram of price
plt.figure(figsize=(8,5))
plt.hist(df["Price"],bins=20)
plt.title("Distribution of House price")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
#step 14 scatter plot
#Area vs price
plt.figure(figsize=(8,6))
plt.scatter(df["Area"],df["Price"])
plt.title("Area vs Price")
plt.xlabel("Area")
plt.ylabel("Price")
plt.show()

# %%
#step 15 Bedrooms vs price
plt.figure(figsize=(8,6))
plt.scatter(df["Bedrooms"],df["Price"])
plt.title("Bedrooms vs Price")
plt.xlabel("Bedrooms")
plt.ylabel("Price")
plt.show()

# %%
#step 16 Bathrooms vs price
plt.figure(figsize=(8,6))
plt.scatter(df["Bathrooms"],df["Price"])
plt.title("Bathrooms vs Price")
plt.xlabel("Bathrooms")
plt.ylabel("Price")
plt.show()

# %%
# Step 17 parking count
df["Parking"].value_counts().plot(kind="bar")
plt.title("Parking Availability")
plt.show()

# %%
#step 18 correlation matrix
correlation = df.corr()
correlation
# student learn
# which feature affects price most
# Out:
#                    Area  Bedrooms  Bathrooms       Age  Distance_City  \
# Area           1.000000  0.185810   0.027056 -0.049376      -0.020451
# Bedrooms       0.185810  1.000000   0.030408  0.050272       0.106369
# Bathrooms      0.027056  0.030408   1.000000  0.053218       0.122258
# Age           -0.049376  0.050272   0.053218  1.000000      -0.059550
# Distance_City -0.020451  0.106369   0.122258 -0.059550       1.000000
# Parking        0.068647  0.051584  -0.100711 -0.037909      -0.068819
# Price          0.917359  0.374433   0.107178 -0.136426      -0.128706
#
#                 Parking     Price
# Area           0.068647  0.917359
# Bedrooms       0.051584  0.374433
# Bathrooms     -0.100711  0.107178
# Age           -0.037909 -0.136426
# Distance_City -0.068819 -0.128706
# Parking        1.000000  0.144416
# Price          0.144416  1.000000

# %%
#step heatmap
plt.figure(figsize=(8,6))
plt.imshow(correlation,cmap="coolwarm")
plt.colorbar()
plt.xticks(range(len(correlation.columns)),correlation.columns,rotation=90)
plt.yticks(range(len(correlation.columns)),correlation.columns)
plt.title("Correlation Matrix")
plt.show()

# %%
#step feature selection
x = df.drop("Price",axis=1)
y = df["Price"]

# %%
# step Train-Test split
x_trian,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
